# %% [markdown]
# <center>
#     <img src="https://gitlab.com/ibm/skills-network/courses/placeholder101/-/raw/master/labs/module%201/images/IDSNlogo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# # **Data Visualization Lab**

# %% [markdown]
# Estimated time needed: **45 to 60** minutes

# %% [markdown]
# In this assignment you will be focusing on the visualization of data.
#
# The data set will be presented to you in the form of a RDBMS.
#
# You will have to use SQL queries to extract the data.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# -   Visualize the distribution of data.
#
# -   Visualize the relationship between two features.
#
# -   Visualize composition of data.
#
# -   Visualize comparison of data.

# %% [markdown]
# <hr>

# %% [markdown]
# ## Demo: How to work with database

# %% [markdown]
# Download database file.

# %%
# !wget https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m4_survey_data.sqlite
# Out:
# --2020-11-22 18:02:38--  https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m4_survey_data.sqlite
# Resolving cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)... 67.228.254.196
# Connecting to cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)|67.228.254.196|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 36679680 (35M) [application/octet-stream]
# Saving to: ‘m4_survey_data.sqlite.2’
#
# m4_survey_data.sqli 100%[===================>]  34.98M  26.7MB/s    in 1.3s
#
# 2020-11-22 18:02:40 (26.7 MB/s) - ‘m4_survey_data.sqlite.2’ saved [36679680/36679680]

# %% [markdown]
# Connect to the database.

# %%
import sqlite3
conn = sqlite3.connect("m4_survey_data.sqlite") # open a database connection

# %% [markdown]
# Import pandas module.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_sql("SELECT * FROM master", conn)
df
# Out:
#        index  Respondent                      MainBranch Hobbyist  \
# 0          0           4  I am a developer by profession       No
# 1          1           9  I am a developer by profession      Yes
# 2          2          13  I am a developer by profession      Yes
# 3          3          16  I am a developer by profession      Yes
# 4          4          17  I am a developer by profession      Yes
# ...      ...         ...                             ...      ...
# 11393  11393       25136  I am a developer by profession      Yes
# 11394  11394       25137  I am a developer by profession      Yes
# 11395  11395       25138  I am a developer by profession      Yes
# 11396  11396       25141  I am a developer by profession      Yes
# 11397  11397       25142  I am a developer by profession      Yes
#
#                                              OpenSourcer  \
# 0                                                  Never
# ...

# %% [markdown]
# ## Demo: How to run an sql query

# %%
# print how many rows are there in the table named 'master'
QUERY = """
SELECT COUNT(*)
FROM master
"""

# the read_sql_query runs the sql query and returns the data as a dataframe
df = pd.read_sql_query(QUERY,conn)
df.head()
# Out:
#    COUNT(*)
# 0     11398

# %% [markdown]
# ## Demo: How to list all tables

# %%
# print all the tables names in the database
QUERY = """
SELECT name as Table_Name FROM
sqlite_master WHERE
type = 'table'
"""
# the read_sql_query runs the sql query and returns the data as a dataframe
pd.read_sql_query(QUERY,conn)
# Out:
#                 Table_Name
# 0                 EduOther
# 1                  DevType
# 2                  LastInt
# 3               JobFactors
# 4                 WorkPlan
# 5            WorkChallenge
# 6       LanguageWorkedWith
# 7   LanguageDesireNextYear
# 8       DatabaseWorkedWith
# 9   DatabaseDesireNextYear
# 10      PlatformWorkedWith
# 11  PlatformDesireNextYear
# 12      WebFrameWorkedWith
# 13  WebFrameDesireNextYear
# 14      MiscTechWorkedWith
# 15  MiscTechDesireNextYear
# 16              DevEnviron
# 17              Containers
# 18               SOVisitTo
# 19            SONewContent
# 20                  Gender
# 21               Sexuality
# 22               Ethnicity
# 23                  master

# %% [markdown]
# ## Demo: How to run a group by query

# %%
QUERY = """
SELECT Age,COUNT(*) as count
FROM master
group by age
order by age
"""
pd.read_sql_query(QUERY,conn)
# Out:
#      Age  count
# 0    NaN    287
# 1   16.0      3
# 2   17.0      6
# 3   18.0     29
# 4   19.0     78
# 5   20.0    109
# 6   21.0    203
# 7   22.0    406
# 8   23.0    581
# 9   24.0    679
# 10  25.0    738
# 11  26.0    720
# 12  27.0    724
# 13  28.0    787
# 14  29.0    697
# 15  30.0    651
# 16  31.0    531
# 17  32.0    489
# 18  33.0    483
# 19  34.0    395
# 20  35.0    393
# 21  36.0    308
# 22  37.0    280
# 23  38.0    279
# 24  39.0    232
# 25  40.0    187
# 26  41.0    136
# 27  42.0    162
# 28  43.0    100
# 29  44.0     95
# 30  45.0     85
# 31  46.0     66
# 32  47.0     68
# 33  48.0     64
# 34  49.0     66
# 35  50.0     57
# 36  51.0     29
# 37  52.0     41
# 38  53.0     32
# 39  54.0     26
# 40  55.0     13
# 41  56.0     16
# 42  57.0     11
# 43  58.0     12
# 44  59.0     11
# 45  60.0      2
# 46  61.0     10
# 47  62.0      5
# 48  63.0      7
# 49  65.0      2
# 50  66.0      1
# 51  67.0      1
# 52  69.0      1
# 53  71.0      2
# ...

# %% [markdown]
# ## Demo: How to describe a table

# %%
table_name = 'master'  # the table you wish to describe

QUERY = """
SELECT sql FROM sqlite_master
WHERE name= '{}'
""".format(table_name)

df = pd.read_sql_query(QUERY,conn)
print(df.iat[0,0])
# Out:
# CREATE TABLE "master" (
# "index" INTEGER,
#   "Respondent" INTEGER,
#   "MainBranch" TEXT,
#   "Hobbyist" TEXT,
#   "OpenSourcer" TEXT,
#   "OpenSource" TEXT,
#   "Employment" TEXT,
#   "Country" TEXT,
#   "Student" TEXT,
#   "EdLevel" TEXT,
#   "UndergradMajor" TEXT,
#   "OrgSize" TEXT,
#   "YearsCode" TEXT,
#   "Age1stCode" TEXT,
#   "YearsCodePro" TEXT,
#   "CareerSat" TEXT,
#   "JobSat" TEXT,
#   "MgrIdiot" TEXT,
#   "MgrMoney" TEXT,
#   "MgrWant" TEXT,
#   "JobSeek" TEXT,
#   "LastHireDate" TEXT,
#   "FizzBuzz" TEXT,
#   "ResumeUpdate" TEXT,
#   "CurrencySymbol" TEXT,
#   "CurrencyDesc" TEXT,
#   "CompTotal" REAL,
#   "CompFreq" TEXT,
#   "ConvertedComp" REAL,
#   "WorkWeekHrs" REAL,
#   "WorkRemote" TEXT,
#   "WorkLoc" TEXT,
#   "ImpSyn" TEXT,
#   "CodeRev" TEXT,
#   "CodeRevHrs" REAL,
#   "UnitTests" TEXT,
#   "PurchaseHow" TEXT,
#   "PurchaseWhat" TEXT,
#   "OpSys" TEXT,
#   "BlockchainOrg" TEXT,
#   "BlockchainIs" TEXT,
#   "BetterLife" TEXT,
#   "ITperson" TEXT,
# ...

# %% [markdown]
# # Hands-on Lab

# %% [markdown]
# ## Visualizing distribution of data

# %% [markdown]
# ### Histograms

# %% [markdown]
# Plot a histogram of `ConvertedComp.`

# %%
# your code goes here
plt.figure(figsize=(10,5))
sns.distplot(a=df["ConvertedComp"],bins=20,kde=False)
plt.show()

# %% [markdown]
# ### Box Plots

# %% [markdown]
# Plot a box plot of `Age.`

# %%
# your code goes here
plt.figure(figsize=(10,5))
sns.boxplot(x=df.Age, data=df)
plt.show()

# %% [markdown]
# ## Visualizing relationships in data

# %% [markdown]
# ### Scatter Plots

# %% [markdown]
# Create a scatter plot of `Age` and `WorkWeekHrs.`

# %%
# your code goes here
plt.figure(figsize=(20,10))
sns.scatterplot(x=df.Age,y=df.WorkWeekHrs, data=df)
plt.show()

# %%
df[['Age','WorkWeekHrs']].corr()
# Out:
#                   Age  WorkWeekHrs
# Age          1.000000     0.036517
# WorkWeekHrs  0.036517     1.000000

# %% [markdown]
# ### Bubble Plots

# %% [markdown]
# Create a bubble plot of `WorkWeekHrs` and `CodeRevHrs`, use `Age` column as bubble size.

# %%
# your code goes here
plt.figure(figsize=(10,5))
plt.scatter(x=df.WorkWeekHrs, y=df.CodeRevHrs, c='green', alpha=0.2, s=df.Age*10)
plt.show()

# %% [markdown]
# ## Visualizing composition of data

# %% [markdown]
# ### Pie Charts

# %% [markdown]
# Create a pie chart of the top 5 databases that respondents wish to learn next year. Label the pie chart with database names. Display percentages of each database on the pie chart.

# %%
# your code goes here
df2 = pd.read_sql("SELECT * FROM DatabaseDesireNextYear", conn)
df2.columns
# Out:
# Index(['Respondent', 'DatabaseDesireNextYear'], dtype='object')

# %%
df2
# Out:
#        Respondent DatabaseDesireNextYear
# 0               4                  MySQL
# 1               4                 SQLite
# 2               9             PostgreSQL
# 3               9                  Redis
# 4               9                 SQLite
# ...           ...                    ...
# 29570       25141          Elasticsearch
# 29571       25141                MongoDB
# 29572       25141   Microsoft SQL Server
# 29573       25141                  Redis
# 29574       25142             PostgreSQL
#
# [29575 rows x 2 columns]

# %%
df2.groupby("DatabaseDesireNextYear").count()
# Out:
#                         Respondent
# DatabaseDesireNextYear
# Cassandra                     1003
# Couchbase                      390
# DynamoDB                      1044
# Elasticsearch                 2856
# Firebase                      1650
# MariaDB                       1385
# Microsoft SQL Server          2706
# MongoDB                       3649
# MySQL                         3281
# Oracle                         870
# Other(s):                      645
# PostgreSQL                    4328
# Redis                         3331
# SQLite                        2437

# %%
y = pd.DataFrame(df2.groupby("DatabaseDesireNextYear").count())
y
# Out:
#                         Respondent
# DatabaseDesireNextYear
# Cassandra                     1003
# Couchbase                      390
# DynamoDB                      1044
# Elasticsearch                 2856
# Firebase                      1650
# MariaDB                       1385
# Microsoft SQL Server          2706
# MongoDB                       3649
# MySQL                         3281
# Oracle                         870
# Other(s):                      645
# PostgreSQL                    4328
# Redis                         3331
# SQLite                        2437

# %%
y.sort_values(by="Respondent", ascending=False)
# Out:
#                         Respondent
# DatabaseDesireNextYear
# PostgreSQL                    4328
# MongoDB                       3649
# Redis                         3331
# MySQL                         3281
# Elasticsearch                 2856
# Microsoft SQL Server          2706
# SQLite                        2437
# Firebase                      1650
# MariaDB                       1385
# DynamoDB                      1044
# Cassandra                     1003
# Oracle                         870
# Other(s):                      645
# Couchbase                      390

# %%
y= y.nlargest(5,"Respondent")
y
# Out:
#                         Respondent
# DatabaseDesireNextYear
# PostgreSQL                    4328
# MongoDB                       3649
# Redis                         3331
# MySQL                         3281
# Elasticsearch                 2856

# %%
plt.figure(figsize=(10,10))
plt.pie(y.Respondent, labels=['PostgreSQL','MongoDB','Redis','MySQL','Elasticsearch'],
       autopct='%.2f%%')
plt.title("DataBase Worked With Percentages")
plt.show()

# %%
df10 = pd.read_sql("SELECT * FROM LanguageDesireNextYear", conn)
df10.columns
# Out:
# Index(['Respondent', 'LanguageDesireNextYear'], dtype='object')

# %%
df10
# Out:
#        Respondent LanguageDesireNextYear
# 0               4                      C
# 1               4                     C#
# 2               4             JavaScript
# 3               4                    SQL
# 4               9  Bash/Shell/PowerShell
# ...           ...                    ...
# 55759       25142  Bash/Shell/PowerShell
# 55760       25142                      C
# 55761       25142                    C++
# 55762       25142                 Python
# 55763       25142                      R
#
# [55764 rows x 2 columns]

# %%
df14=df10.groupby('LanguageDesireNextYear').count()
df14
# Out:
#                         Respondent
# LanguageDesireNextYear
# Assembly                       336
# Bash/Shell/PowerShell         3097
# C                             1028
# C#                            3591
# C++                           1633
# Clojure                        413
# Dart                           610
# Elixir                         620
# Erlang                         310
# F#                             621
# Go                            2759
# HTML/CSS                      5328
# Java                          2953
# JavaScript                    6630
# Kotlin                        1890
# Objective-C                    310
# Other(s):                      836
# PHP                           1457
# Python                        5239
# R                              850
# Ruby                          1029
# Rust                          1520
# SQL                           5012
# Scala                          879
# Swift                         1179
# ...

# %%
df14.sort_values(by= 'Respondent', ascending=False)
# Out:
#                         Respondent
# LanguageDesireNextYear
# JavaScript                    6630
# HTML/CSS                      5328
# Python                        5239
# SQL                           5012
# TypeScript                    4088
# C#                            3591
# Bash/Shell/PowerShell         3097
# Java                          2953
# Go                            2759
# Kotlin                        1890
# C++                           1633
# Rust                          1520
# PHP                           1457
# WebAssembly                   1397
# Swift                         1179
# Ruby                          1029
# C                             1028
# Scala                          879
# R                              850
# Other(s):                      836
# F#                             621
# Elixir                         620
# Dart                           610
# Clojure                        413
# Assembly                       336
# ...

# %%
df11 = pd.read_sql("SELECT * FROM DatabaseWorkedWith", conn)
df11
# Out:
#        Respondent    DatabaseWorkedWith
# 0               4                 MySQL
# 1               4                SQLite
# 2               9              DynamoDB
# 3               9            PostgreSQL
# 4               9                SQLite
# ...           ...                   ...
# 31370       25137                 MySQL
# 31371       25138            PostgreSQL
# 31372       25141  Microsoft SQL Server
# 31373       25141                 Redis
# 31374       25142            PostgreSQL
#
# [31375 rows x 2 columns]

# %%
df12=df11['Respondent'].drop_duplicates(keep=False).to_frame()
df12
# Out:
#        Respondent
# 32             25
# 43             38
# 102            70
# 105            74
# 106            75
# ...           ...
# 31361       25128
# 31369       25136
# 31370       25137
# 31371       25138
# 31374       25142
#
# [2515 rows x 1 columns]

# %%
df12['DatabaseWorkedWith']=df11['DatabaseWorkedWith']
df12
# Out:
#        Respondent    DatabaseWorkedWith
# 32             25                 MySQL
# 43             38  Microsoft SQL Server
# 102            70  Microsoft SQL Server
# 105            74              DynamoDB
# 106            75               MongoDB
# ...           ...                   ...
# 31361       25128                SQLite
# 31369       25136  Microsoft SQL Server
# 31370       25137                 MySQL
# 31371       25138            PostgreSQL
# 31374       25142            PostgreSQL
#
# [2515 rows x 2 columns]

# %%
df12.groupby('DatabaseWorkedWith').count()
# Out:
#                       Respondent
# DatabaseWorkedWith
# Cassandra                     10
# Couchbase                      8
# DynamoDB                      28
# Elasticsearch                 27
# Firebase                      90
# MariaDB                       44
# Microsoft SQL Server         845
# MongoDB                      170
# MySQL                        474
# Oracle                       162
# Other(s):                     94
# PostgreSQL                   351
# Redis                         20
# SQLite                       192

# %%
df16= pd.read_sql("SELECT * FROM DevType", conn)
df16
# Out:
#        Respondent                     DevType
# 0               4       Developer, full-stack
# 1               9      Database administrator
# 2               9         Developer, back-end
# 3               9        Developer, front-end
# 4               9       Developer, full-stack
# ...           ...                         ...
# 35309       25141           Developer, mobile
# 35310       25141              Engineer, data
# 35311       25141  Engineer, site reliability
# 35312       25141        System administrator
# 35313       25142         Academic researcher
#
# [35314 rows x 2 columns]

# %%
df17=df16.groupby('DevType').count()
df17
# Out:
#                                                Respondent
# DevType
# Academic researcher                                   556
# Data or business analyst                              802
# Data scientist or machine learning specialist         803
# Database administrator                               1413
# Designer                                              988
# DevOps specialist                                    1639
# Developer, QA or test                                 911
# Developer, back-end                                  6290
# Developer, desktop or enterprise applications        2575
# Developer, embedded applications or devices           854
# Developer, front-end                                 3920
# Developer, full-stack                                6928
# Developer, game or graphics                           472
# Developer, mobile                                    1959
# Educator                                              514
# ...

# %%
df17.sort_values(by='Respondent', ascending=False)
# Out:
#                                                Respondent
# DevType
# Developer, full-stack                                6928
# Developer, back-end                                  6290
# Developer, front-end                                 3920
# Developer, desktop or enterprise applications        2575
# Developer, mobile                                    1959
# DevOps specialist                                    1639
# Database administrator                               1413
# System administrator                                 1202
# Designer                                              988
# Developer, QA or test                                 911
# Developer, embedded applications or devices           854
# Engineer, data                                        832
# Data scientist or machine learning specialist         803
# Data or business analyst                              802
# Student                                               766
# ...

# %%
AV=df[df['Age'].between(25.0,30.0)]
AV
# Out:
#        index  Respondent                      MainBranch Hobbyist  \
# 2          2          13  I am a developer by profession      Yes
# 3          3          16  I am a developer by profession      Yes
# 4          4          17  I am a developer by profession      Yes
# 16        16          43  I am a developer by profession      Yes
# 24        24          60  I am a developer by profession      Yes
# ...      ...         ...                             ...      ...
# 11389  11389       25125  I am a developer by profession       No
# 11390  11390       25128  I am a developer by profession      Yes
# 11394  11394       25137  I am a developer by profession      Yes
# 11396  11396       25141  I am a developer by profession      Yes
# 11397  11397       25142  I am a developer by profession      Yes
#
#                                              OpenSourcer  \
# 2      Less than once a month but more than once per ...
# ...

# %%
AV[['Age','ConvertedComp']].corr()
# Out:
#                     Age  ConvertedComp
# Age            1.000000       0.062712
# ConvertedComp  0.062712       1.000000

# %% [markdown]
# ### Stacked Charts

# %% [markdown]
# Create a stacked chart of median `WorkWeekHrs` and `CodeRevHrs` for the age group 30 to 35.

# %%
S=df[df['Age'].between(30.0,35.0)]
S
# Out:
#        index  Respondent                      MainBranch Hobbyist  \
# 5          5          19  I am a developer by profession      Yes
# 11        11          26  I am a developer by profession      Yes
# 12        12          29  I am a developer by profession      Yes
# 18        18          49  I am a developer by profession      Yes
# 22        22          56  I am a developer by profession       No
# ...      ...         ...                             ...      ...
# 11385  11385       25120  I am a developer by profession      Yes
# 11391  11391       25133  I am a developer by profession       No
# 11392  11392       25134  I am a developer by profession      Yes
# 11395  11395       25138  I am a developer by profession      Yes
# 11397  11397       25142  I am a developer by profession      Yes
#
#                                              OpenSourcer  \
# 5                                                  Never
# ...

# %%
# your code goes here
S['w_median']=S['WorkWeekHrs'].median()
S
# Out:
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
#        index  Respondent                      MainBranch Hobbyist  \
# 5          5          19  I am a developer by profession      Yes
# 11        11          26  I am a developer by profession      Yes
# 12        12          29  I am a developer by profession      Yes
# 18        18          49  I am a developer by profession      Yes
# 22        22          56  I am a developer by profession       No
# ...      ...         ...                             ...      ...
# 11385  11385       25120  I am a developer by profession      Yes
# ...

# %%
S['c_median']=S['CodeRevHrs'].median()
S
# Out:
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
#        index  Respondent                      MainBranch Hobbyist  \
# 5          5          19  I am a developer by profession      Yes
# 11        11          26  I am a developer by profession      Yes
# 12        12          29  I am a developer by profession      Yes
# 18        18          49  I am a developer by profession      Yes
# 22        22          56  I am a developer by profession       No
# ...      ...         ...                             ...      ...
# 11385  11385       25120  I am a developer by profession      Yes
# ...

# %%
df4 = pd.DataFrame({'Hours': [40, 4]})
df5=df4.transpose()
df5.columns=['WorkWeekHrs','CodeRevHrs']
df5.index=['Ages 30-35']
df5
# Out:
#             WorkWeekHrs  CodeRevHrs
# Ages 30-35           40           4

# %%
df5.plot(kind='bar',figsize=(10,5), stacked=True)
plt.legend()
plt.show()

# %% [markdown]
# ## Visualizing comparison of data

# %% [markdown]
# ### Line Chart

# %% [markdown]
# Plot the median `ConvertedComp` for all ages from 45 to 60.

# %%
# your code goes here
L=df[df['Age'].between(45.0,60.0)]
L
# Out:
#        index  Respondent                                         MainBranch  \
# 7          7          22                     I am a developer by profession
# 50        50         111                     I am a developer by profession
# 66        66         144                     I am a developer by profession
# 75        75         164                     I am a developer by profession
# 93        93         202                     I am a developer by profession
# ...      ...         ...                                                ...
# 11342  11342       25016                     I am a developer by profession
# 11345  11345       25022  I am not primarily a developer, but I write co...
# 11350  11350       25036                     I am a developer by profession
# 11372  11372       25091                     I am a developer by profession
# 11373  11373       25092                     I am a developer by profession
#
# ...

# %%
df3=L[['Age','ConvertedComp']]
df3
# Out:
#         Age  ConvertedComp
# 7      47.0       103000.0
# 50     54.0            NaN
# 66     47.0        54996.0
# 75     47.0        62807.0
# 93     45.0        72522.0
# ...     ...            ...
# 11342  45.0        76339.0
# 11345  46.0        68705.0
# 11350  48.0       300000.0
# 11372  50.0        87668.0
# 11373  50.0        59652.0
#
# [599 rows x 2 columns]

# %%
M=df3.groupby(['Age']).median()
M
# Out:
#       ConvertedComp
# Age
# 45.0        90330.0
# 46.0        91593.0
# 47.0        91606.0
# 48.0       105750.0
# 49.0        85248.0
# 50.0        95000.0
# 51.0       100000.0
# 52.0       105500.0
# 53.0       100463.0
# 54.0       121000.0
# 55.0       119000.0
# 56.0        99530.5
# 57.0       117578.0
# 58.0       108000.0
# 59.0       110000.0
# 60.0       132287.5

# %%
M.plot(kind='line',linewidth=4, figsize=(10,5))
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ### Bar Chart

# %% [markdown]
# Create a horizontal bar chart using column `MainBranch.`

# %%
# your code goes here
df6=df['MainBranch'].value_counts().sort_values(ascending=True).to_frame()
df6
# Out:
#                                                     MainBranch
# I am not primarily a developer, but I write cod...         780
# I am a developer by profession                           10618

# %%
label=list(df6['MainBranch'])

df6.plot(kind='barh', figsize=(13,5))


for i, value in enumerate(label):
    plt.text(value, i, str(value), color='black', fontweight='bold')
plt.show()

# %%
conn.close()

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2020-10-17        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |

# %% [markdown]
#  Copyright © 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license?cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).
